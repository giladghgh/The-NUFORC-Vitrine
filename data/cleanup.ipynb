# %% [markdown]
# ### Preamble

# %%
# %%html
# <script>
#     // AUTORUN ALL CELLS ON NOTEBOOK-LOAD!
#     require(
#         ['base/js/namespace', 'jquery'],
#         function(jupyter, $) {
#             $(jupyter.events).on("kernel_ready.Kernel", function () {
#                 console.log("Auto-running all cells-below...");
#                 jupyter.actions.call('jupyter-notebook:run-all-cells-below');
#                 jupyter.actions.call('jupyter-notebook:save-notebook');
#             });
#         }
#     );
# </script>

# %%
# PIP INSTALLS

# for data handling:
#! pip install pandas

# for reading Duration entries:
#! pip install word2number

# for imputing lat/long:
#! pip install geopy

# %%
# IMPORTS

import re
import pandas as pd
import datetime as dt

from numpy import select,isnan
from functools import partial
from geopy.geocoders import Nominatim,OpenCage
from geopy.extra.rate_limiter import RateLimiter


# initialise the geopy API
ua = \
"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.88 Safari/537.36"
k = \
"cc6fe73ae2a64a7c937b8f8553dce0a1"
Geogetter = partial(Nominatim(user_agent=ua).geocode , language='en')
#Geogetter = partial(OpenCage(k).geocode , language='en')
Geoget = RateLimiter(Geogetter , min_delay_seconds=1)

# %%
# CONSTANTS

# reference states for relocation:
statesUSA = {
    'AL': 'Alabama',
    'AK': 'Alaska',
    'AS': 'American Samoa',
    'AZ': 'Arizona',
    'AR': 'Arkansas',
    'CA': 'California',
    'CO': 'Colorado',
    'CT': 'Connecticut',
    'DE': 'Delaware',
    'DC': 'District of Columbia',
    'FL': 'Florida',
    'GA': 'Georgia',
    'GU': 'Guam',
    'HI': 'Hawaii',
    'ID': 'Idaho',
    'IL': 'Illinois',
    'IN': 'Indiana',
    'IA': 'Iowa',
    'KS': 'Kansas',
    'KY': 'Kentucky',
    'LA': 'Louisiana',
    'ME': 'Maine',
    'MD': 'Maryland',
    'MA': 'Massachusetts',
    'MI': 'Michigan',
    'MN': 'Minnesota',
    'MS': 'Mississippi',
    'MO': 'Missouri',
    'MT': 'Montana',
    'NE': 'Nebraska',
    'NV': 'Nevada',
    'NH': 'New Hampshire',
    'NJ': 'New Jersey',
    'NM': 'New Mexico',
    'NY': 'New York',
    'NC': 'North Carolina',
    'ND': 'North Dakota',
    'MP': 'Northern Mariana Islands',
    'OH': 'Ohio',
    'OK': 'Oklahoma',
    'OR': 'Oregon',
    'PA': 'Pennsylvania',
    'PR': 'Puerto Rico',
    'RI': 'Rhode Island',
    'SC': 'South Carolina',
    'SD': 'South Dakota',
    'TN': 'Tennessee',
    'TX': 'Texas',
    'UT': 'Utah',
    'VT': 'Vermont',
    'VA': 'Virginia',
    'WA': 'Washington',
    'WV': 'West Virginia',
    'WI': 'Wisconsin',
    'WY': 'Wyoming'
}

statesCND = {
  'AB': 'Alberta',
  'BC': 'British Columbia',
  'MB': 'Manitoba',
  'NB': 'New Brunswick',
  'NL': 'Newfoundland and Labrador',
  'NS': 'Nova Scotia',
  'NT': 'Northwest Territories',
  'NU': 'Nunavut',
  'ON': 'Ontario',
  'PE': 'Prince Edward Island',
  'QC': 'Quebec',
  'SK': 'Saskatchewan',
  'YT': 'Yukon'
}

allStates = {**statesUSA, **statesCND}

# for better shape classification:
shapeMapping = {"light"    :"Flash",
                "circle"   :"Orb",
                "teardrop" :"Teardrop",
                "cigar"    :"Cylinder",
                "disk"     :"Disk",
                "unknown"  :"Indiscernible",
                "oval"     :"Egg",
                "other"    :"Other",
                "sphere"   :"Orb",
                "changing" :"Metamorphing",
                "formation":"Swarm",
                "flash"    :"Flash",
                "chevron"  :"Chevron",
                "0"        :"Orb",
                "triangle" :"Chevron",
                "fireball" :"Flash",
                "cross"    :"Cross",
                "rectangle":"Rectangle",
                "diamond"  :"Diamond",
                "cylinder" :"Cylinder",
                "egg"      :"Egg",
                "cone"     :"Cone"}

# %% [markdown]
# ### Functions

# %%
# PRIVATE

def _readTime(freetext):
    """ Extract datetime text or (value,scale) text pair into pandas.Timedelta format. """
    # not sure how I'll do this. Depends on how cleanupDuration is designed.
    pass


def _countryName(geo):
    name = geo.address.split(', ')[-1]
    return name if 'United States' not in name else 'United States'


def _switchGeo(m,city,abbrev):
    address = city
    if abbrev in allStates.keys():
        address += ", "+allStates[abbrev]

    geo = Geoget(address)
    if not geo:
        print(city)
        return (None,None,None)
    else:
        return {
            3 : ( _countryName(geo) , geo.latitude , geo.longitude ),
            2 : ( None , geo.latitude , geo.longitude ),
            1 : ( _countryName(geo) , None , None )
        }[m]

# %%
# PUBLIC

def readDuration(text):
    """ Using NLP-esque procedures to remedy the godless decision to enter duration data as freetext. """
    # each Duration entry is made of any number of components (hopefully just 1 or 2)
    # component is DATETIME (15:38 or 15.38 or 1538) or PAIR (value-scale pair "3 minutes")
    # entry is DICTUM (1 component, e.g. "3 minutes") or SPAN (2 components, "3-5 seconds")
    # SPECIALTIES:
    # "night"/"dusk"/"dawn"     [08:00:00] e.g. "dusk till dawn", "all night"
    # "twenty mins"             [00:20:00] transcribe English to digits
    # "ongoing"/"still going"     [null]   nullify BUT add "ongoing reports"
    # "0"                       [00:00:00] instant
    # DATETIME DICTUM:
    # 18:00                       [null]   nullify
    # 3:00am                      [null]   nullify
    #
    # PAIR DICTUM:
    # 6MINS                     [00:34:00] standardise
    # 3 minutes and 4 seconds   [00:03:04] fuse
    # 3                         [00:03:00] value but no scale given, assume m
    # minutes                   [00:00:05] scale but no value given, assume 5
    # hour                      [01:00:00] detect plurality
    #
    #
    # for SPANS, don't bother with delims as there's too many possibilities.
    # DATETIME SPAN:
    # 18:00 - 18:34             [00:34:00] difference
    #
    # PAIR SPAN
    # 3-5 minutes               [00:04:00] 2v 1s = average
    # 3/5 minutes               [00:04:00] 2v 1s = average
    # 2 seconds - 9 minutes     [00:09:02] 2v 2s = fuse
    #
    #
    # SPECIAL CONSIDERATIONS:
    # 1: 45 mins                [00:01:45] -_-
    # 12 mon                    [00:12:00] "mon" -> "min"
    # entries like "ongoing" can do one. if there's no component as above, it's null to me.
    words = re.split('[\s]' , text)
    dur = words
    return dur


def imputeLocal(states):
    """ More acute country labelling. """
    # For 554 "U.S." entries, a state isn't even given. A lot of these are foreign cities
    #  without even an American town named after them, meaning the label is plainly incorrect.
    #  A few are also Puerto Rican towns, so I included it in the set of (American) States.
    conds = [
        states.isnull(),
        states.isin( set(statesUSA.keys()) ),
        states.isin( set(statesCND.keys()) )
    ]
    choices = [None , 'United States' , 'Canada']        
    return select(conds , choices)


def imputeWeb(missinglist , cities , states):
    overlay = [ _switchGeo( m,city,state ) if m>0 else (None,None,None) for m,city,state in zip(missinglist,cities,states) ]
    return pd.DataFrame( overlay , columns=['Country','Latitude','Longitude'] )

# %% [markdown]
# ### Mains

# %%
if __name__ == '__main__':
    # TASKS:
    #  1
    #  2
    #  3
    #  4
    # (5)
    # ...
    for i in range(8):
        file = 'nuforc'+str(i+1)
        #file = 'sample'
        DF = pd.read_excel( file+'.xlsx' )
        countryCodes = pd.read_excel(
            'country data.xlsx',
            sheet_name='codes'
        )
        
        # clean up dates/times:
        DF['Date'] = DF.Date.dt.date
        #DF['Time'] = DF.Time.replace(-1,None)

        # more acute shape classification:
        DF['Shape'] = DF.Shape.map(shapeMapping).astype('category')

        # impute locally (Country):
        countries_old = DF.Country.copy()
        DF['Country'] = imputeLocal(DF.State)

        # impute off the web (Country, Latitude, Longitude):
        if True:
            toImpute = ['Country','Latitude','Longitude']
            missingnos = DF[toImpute].isnull().sum(axis=1).to_list()
            DF[toImpute] = DF[toImpute].combine_first(
                imputeWeb(missingnos , DF.City.values , DF.State.values)
            )
        
        # reinstate original country if no better guess
        DF['Country'] = DF.Country.combine_first( countries_old )

        # comprehend Duration freetext:
        if False:
            DF['Duration'] = DF.Duration.map(
                readDuration,
                na_action='ignore'
            )

        print(i, "\n" , DF)
        DF.to_excel( file+'_final.xlsx' )
# Out:
# Vacaville or Fairfield
# Narraganssett
# Cape May Wildwood Crest
# Lake Wiley
# Short Gap
# BAYRAMÃ‡ HACIBEKRLER KÃ–YÃœ
# Karnata Gadak
# West Windsor
# SuliszÃ³w, Wietokrzyskie
# Louisvile
# Bozra
# Monterey Bay Area
# Los Gatos Mountains
# South Myrtle Beach
# Marine park Bklyn
# Coolridge
# Nicassio
# Indian Reservation on way to Barona Casino
# Burl County
# Fort Olgethorpe
# Zanesvill
# Mojave
# Savanagh
# Sanra Rosa
# Unspecified location
# PHONEX
# Woodland hillls
# Chesterfiled
# Newbrighton
# Lake Hamiton
# Appointee Falls
# Larkesville
# Newbrighton
# Ballanger County line
# Reverside
# International waters
# Russell to Hays
# Everywhere
# Pojoque
# Shinston
# Kissimme
# Langely
# Cody and Wapiti
# Lincoln Boro
# Pottstown - Trenton
# Lampeter-Strasburg, Reading
# Newoort Beach
# Bay Minnette
# Shokapee
# Maison
# Trenyon
# Christney
# Barrow-in-Furness
# North Myrtle Beach
# Grandmound
# New Johnsnville
# Chennai
# Karmala
# Sedonna
# Sahuarita
# Evertee
# Chiraco Summit
# In-flight; above AZ
# Albatera
# Tenterden
# Portlamd
# Crystal Mt. Ski Resort
# Mount Rainier area
# Petite Rivier
# Abbotsfort
# Margate
# Assumpsic
# Cloverdate
# Lahania
# Stoninigton
# Longbranch
# Deerlodge
# In-flight sighting
# Elkmomt
# FÃ¼rth
# Taensa Parish
# Cape Coral
# Pine Valley Mountains
# Indian Yake
# Canfon
# Colorado Sprigns
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('Lohman, Missouri',), **{}).
# Traceback (most recent call last):
#   File "D:\Gilad\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 426, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "D:\Gilad\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 421, in _make_request
#     httplib_response = conn.getresponse()
#   File "D:\Gilad\anaconda3\lib\http\client.py", line 1332, in getresponse
#     response.begin()
#   File "D:\Gilad\anaconda3\lib\http\client.py", line 303, in begin
#     version, status, reason = self._read_status()
#   File "D:\Gilad\anaconda3\lib\http\client.py", line 264, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "D:\Gilad\anaconda3\lib\socket.py", line 669, in readinto
#     return self._sock.recv_into(b)
#   File "D:\Gilad\anaconda3\lib\ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "D:\Gilad\anaconda3\lib\ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\Gilad\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 670, in urlopen
#     httplib_response = self._make_request(
#   File "D:\Gilad\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 428, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#   File "D:\Gilad\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 335, in _raise_timeout
#     raise ReadTimeoutError(
# urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\Gilad\anaconda3\lib\site-packages\requests\adapters.py", line 439, in send
#     resp = conn.urlopen(
#   File "D:\Gilad\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 752, in urlopen
#     return self.urlopen(
#   File "D:\Gilad\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 752, in urlopen
#     return self.urlopen(
#   File "D:\Gilad\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 724, in urlopen
#     retries = retries.increment(
#   File "D:\Gilad\anaconda3\lib\site-packages\urllib3\util\retry.py", line 439, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Lohman%2C+Missouri&format=json&limit=1&accept-language=en (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\Gilad\anaconda3\lib\site-packages\geopy\adapters.py", line 383, in _request
#     resp = self.session.get(url, timeout=timeout, headers=headers)
#   File "D:\Gilad\anaconda3\lib\site-packages\requests\sessions.py", line 543, in get
#     return self.request('GET', url, **kwargs)
#   File "D:\Gilad\anaconda3\lib\site-packages\requests\sessions.py", line 530, in request
#     resp = self.send(prep, **send_kwargs)
#   File "D:\Gilad\anaconda3\lib\site-packages\requests\sessions.py", line 643, in send
#     r = adapter.send(request, **kwargs)
#   File "D:\Gilad\anaconda3\lib\site-packages\requests\adapters.py", line 516, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Lohman%2C+Missouri&format=json&limit=1&accept-language=en (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\Gilad\anaconda3\lib\site-packages\geopy\extra\rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#   File "D:\Gilad\anaconda3\lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "D:\Gilad\anaconda3\lib\site-packages\geopy\geocoders\nominatim.py", line 294, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "D:\Gilad\anaconda3\lib\site-packages\geopy\geocoders\base.py", line 360, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "D:\Gilad\anaconda3\lib\site-packages\geopy\adapters.py", line 373, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "D:\Gilad\anaconda3\lib\site-packages\geopy\adapters.py", line 395, in _request
#     raise GeocoderUnavailable(message)
# geopy.exc.GeocoderUnavailable: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Lohman%2C+Missouri&format=json&limit=1&accept-language=en (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# Fort Walton Beac
# Bismarck double ditch
# Cottonwood Lakes, High Sierras
# Cresent Lake - Middle of the Mission Mountain Wilderness - F
# Floristen
# Ogalala
# Lexinton
# Philladelphia
# Myrtal Beach
# Entiay
# Groton
# Nasau bay
# Lakeland- Nashville line
# Cassendra
# Upper Ssaddle River
# Lobeland
# Tilene
# Preson
# Unincorporated Miami-Dade County
# Goffstown
# Drummins
# Route 22 bavington exit
# Pinallas
# Willemstad
# New Glarys
# Woods Mid-NE
# Santa Monica & Brentwood
# Bonneylake
# Kailua Oahu
# Pickneyville
# Denvee
# Wayneboro
# Guanica to Hormigueros
# Bosque farma
# MaracanaÃº
# Bizerte
# M1 southbound near j8
# Porstmouth
# Thunderchild
# Gulf of Mexico
# Frankin
# Loganstown
# Between Indianola and Canadian
# Manchester
# Smyna
# Riviera Mya
# Porquis Jct.
# Samammish
# Alex Frasre Bridge
# Trinkomalee
# Clarksdale
# Coatsville
# Autin
# Apex-Holly Springs
# North utica
# Deerfield Twnshp
# Hiway 27 and the 6th
# Betton
# Edmonton HWY 2 Southbound
# Pune
# Eden Angola
# Broke.n arrow
# Hicksvllie
# Grandhaven
# Blueash
# Mcenry
# Mount Gildead
# Silverhilll
# DÃºbrava, Å½ilinskÃ½ kraj
# Raniganj/Pashchim Bardhaman
# Springesttbury
# AlcobaÃ§a
# Nitro, buffalo & saint Albanyâ€™s West Virginia
# 5 miles of J six highway 10
# Lahaina
# Palistine
# Haliewa
# Dublin , Coolock, ard na grena
# Corte Madera-Tiburon
# Aberdine
# Aliquippa
# Dzilth-na-o-dithle
# Beal AFB
# Gallon
# Aliquippa
# Fort McDowell looking toward Phoenix
# Jegferson City
# Eugene & Salem
# Above Port Blair
# Ricelake
# Cross Plains
# Leaving Pensacola 30-45 mins outside of Pensacola
# Unknown traveling on rt. 25
# Hauâ€™ula
# Limpopo
# Mescalero Indian Reservation
# Santo AndrÃ©
# 0
#               Date      Time            City State        Country  Shape  \
# 0      2017-08-28  10:20:00     San Gabriel    CA  United States    Orb
# 1      2017-08-28  20:00:00          Odessa    ON         Canada    Orb
# 2      2017-06-23  20:00:00        Paulding    OH  United States  Other
# 3      2017-06-23  20:35:00          Pomona    CA  United States    Orb
# 4      2017-06-23  21:13:00  Virginia Beach    VA  United States  Flash
# ...           ...       ...             ...   ...            ...    ...
# 10834  2019-10-02  20:00:00           Tempe    AZ  United States  Swarm
# 10835  2019-10-02  20:00:00         Bolivar    MO  United States  Flash
# 10836  2019-10-02  20:03:00      North Port    FL  United States  Swarm
# 10837  2019-10-02  22:00:00  Black Mountain    NC  United States  Flash
# 10838  2019-10-02  22:00:00    Marin County    CA  United States    Orb
#
#           Duration                                               Link  \
# 0       70 minutes  http://www.nuforc.org/webreports/135/S135945.html
# 1              NaN  http://www.nuforc.org/webreports/136/S136047.html
# 2      3-5 minutes  http://www.nuforc.org/webreports/134/S134784.html
# 3        5 minutes  http://www.nuforc.org/webreports/134/S134781.html
# 4       30 seconds  http://www.nuforc.org/webreports/134/S134722.html
# ...            ...                                                ...
# 10834    3 minutes  http://www.nuforc.org/webreports/149/S149463.html
# 10835   20 seconds  http://www.nuforc.org/webreports/149/S149405.html
# 10836   20 seconds  http://www.nuforc.org/webreports/149/S149424.html
# 10837    2 minutes  http://www.nuforc.org/webreports/149/S149447.html
# 10838    3 minutes  http://www.nuforc.org/webreports/149/S149436.html
#
#                                                  Comment   Latitude  \
# 0      Stayed stationary for 1 hour than moved 15 mil...  34.097942
# 1      The speed they moved at was faster then the sp...  44.277100
# 2      Dark object flying ahead of a Chinook type hel...  41.131000
# 3      Circular object with multiple red, blue and gr...  34.059723
# 4      Green orb like objects flying in the sky. It w...  36.837301
# ...                                                  ...        ...
# 10834  4 lights in formation over Tempe appear while ...  33.414036
# 10835  2 bright star like lights in the NNW sky two b...  37.642200
# 10836  10/2/19 @ 8:03PM EST  UFO SIGHTING in the 3428...  27.076210
# 10837  Witnessed an orange, slow moving light. Was lo...  35.605000
# 10838  Glowing lights in formation  just south of San...  38.040914
#
#         Longitude
# 0     -118.088901
# 1      -76.720300
# 2      -84.556800
# 3     -117.757725
# 4      -76.061948
# ...           ...
# 10834 -111.920920
# 10835  -93.399600
# 10836  -82.223280
# 10837  -82.313200
# 10838 -122.619964
#
# [10839 rows x 11 columns]
# N. Cascades Nat. Park
# Monterey Bay Area
# Sabdy Springs
# Lethbrdge
# Crawfordville
# Kidderminster, Warwickshire
# Chicago- West Suburbs- Rt 171
# Groten
# Dumfriessire
# Lauglintown
# Algadonis  to Tonopah
# Lawdale
# Brick Town
# Brick Town
# Brick Town
# Port el Kantoui
# Fairfiled
# out in the country not city
# Maale Adummim
# Ottovile
# Hebronville
# Pond Inlet
# Couburg
# Surpriswe
# Anza Borrego State Park
# Biglake
# Theunisen
# Monnroe
# Goffstown
# Deerfield Townsship
# NAS Lemoore
# Knoxville & Gatlinburg
# Gibert
# Wad Rum
# Corolla
# Corolla
# Murrell Inlet
# Madison-Clinton
# Mc cains valley
# Dlbliss state park Lake Tahoe
# Point Pleasant Boro
# Franconia knotch
# Saint Johnâ€™s
# Penna Turnpike I-476 S Lehigh Tunnel
# Westbloomfield
# Palmerola Air Base
# Alaska airspace
# Honululu
# Palmerola Air Base
# South Shirley
# SÃ£o JosÃ© dos Campos
# Katlenburg_Lindau
# Passenger plane, in sea between North Spain and France
# Kaâ€™anapali
# Minnepolis
# Rowve
# Fripp Islands
# Oregon Idaho border
# Shuksin picnic area
# Foz do IguaÃ§u
# SÃ£o Paulo
# Morgan Maumelle
# Newark Airport
# Baileys Harbour
# West Windsor
# Nollensville
# I-76 in between mile marker 318 and 317
# Loyisvillet
# Jensenbeach
# Agusta
# Heightstown
# unsure, possibly Des Moines or Grenville
# WashingtonWhite House
# Nagshead
# ChÃ¢teauguay
# Flat Top Mountain, Cedar Valley
# Valex
# Howard Prairie Lake Resort
# Between Jackson Fla. & Atlanta Ga.
# Arvana-Lamesa
# Haltom Ciy
# NASA shuttle DISCOVERY
# Galconda
# Ink-O-Pah
# Outside of Delaware
# Corvalis
# Lost Park area
# Colombiana
# Felixstowe
# Beaver Damm
# Joshua Tree National Park, Twenty Nine Palms
# PortTownsend
# Bolivar - 170th & 326th Road junction
# Hanford Nuclear Reservation
# Newberry Crater National Monument
# Withyville
# Beirut, Tabariss
# Merriville and Gary
# Myrtle Beach-Cherry Grove
# Escawtawpa
# Pope AFB
# Dunollie, Greymouth
# Myers Spring Canyon
# Iron Moutain
# Port Isable
# Winamuccha
# Leicestershre
# Pullmam
# Massachusets Turnpike
# Manaus-Amazonas
# Wahataka
# Ohio-Michigan border
# Muillca Township
# Joshua Tree National Monument
# Sawerville
# San Fransisco
# Haciendo de Cabanas, Guerrero
# Shanadoah
# Frankort
# Big Bend Natinal Park
# SunnyIsles
# Philippine Sea
# Kawashaway
# Tifton - Omega
# Saint Bonifacious
# New Wimington
# Goldhead State Park
# Bellchester
# Wheatly
# Caladon
# Laundstuhl
# Karues - Patras
# Folenburg
# Higly
# Abadania
# LosAlamos
# Purdy Spitt
# Chesterfeild
# Mullia Hill
# Popping Rock
# Wikitravel
# Paincines
# Sounth Atlantic/Caribbean
# Palos Verdes Peninsula
# Jakes Corners
# Bufod
# Velson Noord
# Songtan/Pyongtaek
# East Windsor
# Gaffnet
# Winter Springs to Sanford
# Camp Taqqadum
# Camp Taqaddum
# Monton
# Shafter VOR
# Forestill
# Bakesrsfield
# Blyville
# Spring Bank Airport
# Washington, D.C. to Kansas City
# Dorood
# West Greenwhich
# Hendersonvlle
# Hwy 168, Bristle Cone Pine Forrest
# Georgtown
# Sharldlow
# Two Egg Mariana
# Fracisville
# West Tibury
# Pichacho Peak
# Dodgeville and Oconomowoc
# Sainte-Anne of Madawaska
# Lake Wasahetchie
# Stoney Creek Metropark ?
# Halidiki
# Quonsett Pt. NAS
# Golqnovci
# Anneville
# Murphuys
# Sullivan & Fenton
# Surry County Nuclear Facility
# Mancheater Center
# Balderton Newark on Trent, Nottinghamshire
# Mayslanding
# Jeckyll Island
# Marhall
# Twinning
# Rapid City, Sioux Falls
# Hieleah
# Masfield
# Vanvouver
# U. S. Navy cruiser
# Surry Nuclear Facility
# Philadelpha
# North Adamas
# Osgood, Pierceville, Milan
# Joshua Tree Nat'l Park
# Argos
# Southigton
# Frodsham/Northwich
# White Sand Missile Range - North Ocuro Peak
# Quatzsite
# Ocalawaha
# Unspecified location
# Ramskate
# CaÃ§ador
# Klickitat Yakima County Line
# Northern Territory
# Fort Suppy
# Vindoen Island
# Talahassee
# North Carolina
# Santa Monica Mountains
# Westlake & Hardy
# Kanehoe
# Rock Hill
# Colordo Springs
# Davill
# Image in movie
# Wahkiki
# Langehorne
# Sanikiluaq
# Milon Keynes
# Marouga
# Panteago
# Santa Rsoa
# Niagra Falls
# Grand Rapids to NYC
# Midwest U. S.
# Reggae on the River
# Pinnacles National Monument
# Petelo
# Cypress Hills - West Block
# Imperial Desert
# Glad Stone
# Wilksboro
# SOHO satellite photo
# Medford and Murphy
# Solome
# East Windsor
# 1
#               Date      Time           City State        Country      Shape  \
# 0      2019-12-12  18:43:00        Chester    VA  United States      Flash
# 1      2019-03-22  18:30:00     Rocky Hill    CT  United States        Orb
# 2      2019-04-17  02:00:00         Ottawa    ON         Canada   Teardrop
# 3      2009-03-15  18:00:00         Peoria    NY  United States   Cylinder
# 4      2019-04-02  20:25:00     Kirbyville    TX  United States       Disk
# ...           ...       ...            ...   ...            ...        ...
# 10835  2006-09-01  01:00:00       Kirkland    WA  United States  Rectangle
# 10836  2006-09-02  03:02:00          Craig    CO  United States        NaN
# 10837  2006-09-03  18:22:00       Aalborg    NaN        Denmark        Orb
# 10838  2006-09-08  20:00:00        Berwick    ME  United States        Egg
# 10839  2006-09-10  21:00:00  Lake Elsinore    CA  United States        Orb
#
#                Duration                                               Link  \
# 0             5 seconds  http://www.nuforc.org/webreports/151/S151739.html
# 1           3-5 seconds  http://www.nuforc.org/webreports/145/S145297.html
# 2            10 seconds  http://www.nuforc.org/webreports/145/S145697.html
# 3             2 minutes  http://www.nuforc.org/webreports/145/S145723.html
# 4            15 minutes  http://www.nuforc.org/webreports/145/S145476.html
# ...                 ...                                                ...
# 10835             5 sec   http://www.nuforc.org/webreports/053/S53688.html
# 10836               NaN   http://www.nuforc.org/webreports/053/S53182.html
# 10837           1-3 min   http://www.nuforc.org/webreports/053/S53224.html
# 10838  1 minute or more   http://www.nuforc.org/webreports/053/S53484.html
# 10839        15 seconds   http://www.nuforc.org/webreports/053/S53776.html
#
#                                                  Comment   Latitude  \
# 0      My wife was driving southeast on a fairly popu...  37.343152
# 1      I think that I may caught a UFO on the NBC Nig...  41.664800
# 2      I was driving towards the intersection of fall...  45.381383
# 3      In Peoria, Arizona, I saw a cigar shaped craft...  42.833673
# 4      The object has flashing lights that are green,...  30.677200
# ...                                                  ...        ...
# 10835  An open rectangle in the sky above Seattle It ...  47.693283
# 10836  upon reading the report of a UFO sighting in C...  40.676200
# 10837  small white object flew a bit slow. i was driv...  57.046263
# 10838  BERWICK MAINE U.F.O my son and myself were wal...  43.304800
# 10839  Floating light suddenly moves slowly then spee...  33.692812
#
#         Longitude
# 0      -77.408582
# 1      -72.639300
# 2      -75.708501
# 3      -77.965007
# 4      -94.005200
# ...           ...
# 10835 -122.196644
# 10836 -107.812600
# 10837    9.921526
# 10838  -70.842100
# 10839 -117.362956
#
# [10840 rows x 11 columns]
# Bethlehen
# Lenhartsville Exit
# Arco Dessert
# In orbit/Space Shuttle
# Unsure
# Parkers Cross Roads
# Ypslianti
# Daytona Beach to Tampa
# Southbloomingvill
# STS Atlantis
# South Coffyvile
# Fort Walton Bech
# STS Atlantis
# STS Atlantis
# Littlerock
# Deham Springs
# highway 78 between Bailey & Bonham, Texas
# East Windsor
# Molly Stark St. Park
# Atlantic and Audubon
# Hanford Nuclear Reservation
# New Jersey Graden State Parkway
# Antwep
# Esterk
# Schaumurg
# Lancster
# Port Shepstine
# Celta
# Gillispie
# Ottway
# Safford & Duncan
# Interstate 84 eastbound; Exit 147
# Fort Collins-St. Louis
# Pecks Lake
# Winslow and Blue anchor
# East Windsor
# Lithiona
# Phoenix and Saguaro Lake
# AHMECGARH
# Paincines
# Paincines
# AL-gonfatha
# Laffolette
# River Falls and Prescott
# Saint Petersburg; Madera Beach
# Suffolk/Cambridgeshire/Essex/London
# Littlerock
# Mainstee
# ForestPark
# Mountian Home
# Halletsville
# LittleRock
# Lanley
# Littlerock
# Mdison
# San Bernadino Mtns.
# Gulf Beeze
# Port Elgion
# Fort Larome
# Castleford Nr Leeds
# Chula Vista campground parking lot, Mt. Pinos
# Jensen Beach
# Lajoskomarom/Mezokomarom
# South Hollan
# Hemsted
# STS 121 NASA footage
# Vierfontein
# Gila Indian Reservation & S. Chandler, Ocotillo area
# Ashgrove
# Pauncetony
# Winters Freeway
# MacaÃ©
# Greers Ferry
# Interstate 80.  Between York, Nebraska and Aurora, Nebraska
# Lake gGaston
# Peonia
# North Topsail
# Broomfield?Lafayette
# Kaiserlautern
# FREEWAY BY AIR FORCE BASE
# Osowatomie
# Paysayten Wilderness
# Baadon
# Yukon Territory
# Myles Inlet
# Angleton & Pearland
# Narragansette
# Arrayo Grande
# On highway; location unknown
# Frederid
# Summit Lake Exit, Hwy 42
# not shure
# Osceloa
# Norfork
# Schuyler County area
# Puerta del Zapatero Mazamitla
# Longjetty
# Ellisville Ballwin Wildwood
# Shandanken
# Oregon coastline
# Donja PuÅ¡a
# Hervery Bay
# Sratford
# Lac de la Sucrerie, 115 km NW of Montreal
# Lac de la Sucrerie, Vendee
# Colle D'Valle Delsa/ Scorgiono
# Fallen Timber Area
# Surry Nuclear Facility
# Alma KOA
# Orafino
# Millersvill
# Orangebury
# Pacifica to Belmont
# Osceola to Kansas City
# North Carolina
# Solavang
# Rehobeth
# Colwynbay
# Cornu
# Anza and Garner Valley
# Brunne, HÃ¤rnÃ¶sand
# Wallhearth
# Workey
# Veagus
# Knoxville and Cleveland
# Selfridge Air National Guard
# Hinton Blewitt, Bristol
# Mindelein
# Appalachin
# Skarysko-Kamienna
# Norh Hollywood
# Edgemoore
# Porsgrun
# Lawrencbeurg
# St Helens, Merseyside
# Oakland or Wanaque
# Carnsville
# Willamsburg
# Byhaila
# Ein Geidi Beach
# Windhall
# Pampatar-Margarita Island
# Bellingham-Lummi
# Tom Sauk Moutain
# NASA TV Broadcast
# Emerald Bay Catalina island
# Augadillla
# Fort Lauderdade
# Willbraham
# Avnol
# Kiimberley
# Arizona or Colorano
# Tupelp
# Russels Point
# Waussau
# Beckeymeyer
# Mountgomery County
# Nicolosi, Sicily
# Shelbville
# Hermosa Brach
# Walpole Island First Nation
# Pickney
# Port Coqitlam
# Rorherham
# Acton or Palmdale
# Temperence
# Chula Vist
# Phenix City & Columbus,Ga
# South New Belrin
# Tailen Bend
# Knoxvile
# Imagrant
# Belmar and Wall Twp.
# SÃ£o Paulo
# Coaltownship
# Altivista
# Philapdlphia
# ???
# Mucie
# Limerick/Clare border
# Morde, Surrey
# Faibourne
# Valley View Hot Springs near crestoneCO.
# Bayview Jetty
# Desside
# Peferlaw
# Thrall
# Caviota
# ReykjavÃ­k
# Enon Vally
# Walterborow
# Yaisu/Fujieda
# Northern Oglala
# Empire and Welsville
# San Sebastiam
# Eaugalle
# Iron Mountian
# Puyallyp
# Las Vegas, Nevada, Airspace
# Norcoss
# 2
#               Date      Time             City State        Country  \
# 0      2006-09-15  01:00:00      Santa Maria    TX  United States
# 1      2006-09-16  01:00:00          Liberty    KY  United States
# 2      2007-05-07  19:10:00        Tauranga    NaN    New Zealand
# 3      2007-05-07  20:10:00      Kansas City    MO  United States
# 4      2007-05-07  21:00:00      West Plains    MO  United States
# ...           ...       ...              ...   ...            ...
# 10835  2010-04-23  03:00:00  Los Altos Hills    CA  United States
# 10836  2008-10-02  05:10:00           Benson    NC  United States
# 10837  2008-10-01  22:45:00        Sunnyvale    CA  United States
# 10838  2010-04-23  01:45:00       Stillwater    MN  United States
# 10839  2010-04-23  12:40:00          Norcoss    GA  United States
#
#               Shape    Duration  \
# 0               Orb  45 minutes
# 1      Metamorphing   3 minutes
# 2               NaN   2 minutes
# 3             Other  45 minutes
# 4             Flash       30min
# ...             ...         ...
# 10835       Chevron         NaN
# 10836         Other   30seconds
# 10837         Other  20 seconds
# 10838           Orb  30 minutes
# 10839         Other  30 Seconds
#
#                                                    Link  \
# 0      http://www.nuforc.org/webreports/053/S53284.html
# 1      http://www.nuforc.org/webreports/053/S53599.html
# 2      http://www.nuforc.org/webreports/056/S56555.html
# 3      http://www.nuforc.org/webreports/056/S56612.html
# 4      http://www.nuforc.org/webreports/056/S56572.html
# ...                                                 ...
# 10835  http://www.nuforc.org/webreports/075/S75157.html
# 10836  http://www.nuforc.org/webreports/066/S66027.html
# 10837  http://www.nuforc.org/webreports/066/S66015.html
# 10838  http://www.nuforc.org/webreports/075/S75178.html
# 10839  http://www.nuforc.org/webreports/075/S75174.html
#
#                                                  Comment   Latitude  \
# 0      Bright object seen hovering over sugar cane fi...  29.479821
# 1      glowing cone/heat/sound/electric disturbance. ...  37.307000
# 2      date: 5th May 2007 time: 7pm  I have just seen... -37.685901
# 3      Bright lights seen in Western sky moving very ...  39.100835
# 4      two small red and white lights circling or cha...  36.724800
# ...                                                  ...        ...
# 10835  Triangle with lights seen hovering near highwa...  37.379700
# 10836  unknown looking craft at about 5:10 pm i was b...  35.417800
# 10837  flashing object with erratic motion Tonight I ...  37.379397
# 10838  A strange glowing / pulsating colored light wa...  45.064800
# 10839  Black "boomerang" over Norcross, GA during thu...        NaN
#
#         Longitude
# 0      -98.722569
# 1      -84.952700
# 2      176.167505
# 3      -94.564479
# 4      -91.894500
# ...           ...
# 10835 -122.137500
# 10836  -78.500500
# 10837 -122.021478
# 10838  -92.847300
# 10839         NaN
#
# [10840 rows x 11 columns]
# New Hatford
# Red Bluff - Dribble Creek Subdivision
# Sierra Nevada Mountains
# I-10 eastbound @ markers 2-65
# Krasdnoyarsk
# McGregor range
# Pomoma
# Viby Sjealland
# Yukon Territory
# Toppsey
# Othello-Pullman
# Brigantine
# Boonton Town
# Volujntown
# Panama City Beach
# Oak Shores Lake Berryessa
# Bellville
# Ralleigh
# Berkley Twsp.
# Eaugalle
# KlaksvÃ­k
# Cape May Courthouse
# Somerviller
# not in one
# Llandudnol
# Jounieh-Jabal Lebnen
# Sarnia
# USS John F. Kennedy
# Corral Hollow road vicinity
# Cape May Courthouse
# Cumberland to Freeport area
# Litha
# Enerson
# Muskokee
# Campground Kendallville
# unsure exact name
# Allegheny State Park
# Sorento
# OujÃ© Bougoumou
# In-flight sighting
# Pushkarmoe
# Machedney Park
# Gracville
# Pounchatola
# Machu Piccu
# New Bedfor
# Mainville
# Antioch Community
# Alpheretta
# Pollockpines
# Wipholt
# ZIP code 20876
# Leeds
# Wurtand
# russlville
# Cataqua
# Achusnet
# Granview
# Linoir City
# Swindon/Didcott
# Williamslake
# New Kensignton
# Close to Wellton
# Feltham
# Acusnet
# Iochwinnoch
# Butte & Bozeman
# Mohawk Valley Mtns.
# Eugen
# RzeszÃ³w
# Melbrook
# Coqutilam
# Unspecified location in WV
# Corn Wale
# Mamria Thethar, Rewari
# Clarksvile
# Shicksinny
# History Channel
# Trinadad
# Northen Georgian Bay
# Barendracht
# Red Pheasant First Nation
# Holland and Grand Haven
# Burson & Wallace
# Kanta
# Palm Bear Lake
# Palm Bear
# Peterborough Lakes
# Charlivox
# Wilmont
# Dargivil
# Seltjarnarnesi
# DÃ¼sseldorf
# Pillar Point Air Base
# Hanford Nuclear Reservation
# Smryna
# Durrells
# Sundsanvik
# Rivrside
# Hikilki
# Islamorado
# Lenexa
# Cherokee Villiage
# Home Front Compound
# Huntsvile
# Westeren Springs
# Berkley Heights
# Maze District, Canyonlands National Park
# Barstow and Needles
# Werisdale
# Urrieta
# Applachian Mountains
# MilanÃƒÂ³wek
# Springdfield
# Ashgrove
# Naval weapons base Fallbrook
# Terre haute outskirts
# Pa'akai Point- Mamalahoha Hwy
# Alvordon
# Bhopal
# Diamond Bar to Riverside
# Bloomsbug
# Ballderson
# Baiting H
# Dealth Valley
# Maroochydore
# Shlangen
# Kingsford Hieghts
# Auburn and Westboro
# Forth Estuary
# Cooper's Rock
# Sierra Vita
# Sweeteater
# Chechauoene
# Miramich
# Brentwood Short's Lake
# Twin Shores
# Hayward-Trego
# Bryant Creek, Rippe access
# Walatka
# Acusnet
# Clear Creek East Resort
# Charubusco
# Jamesville
# Cedarbug
# Moshiem
# Goldens Bridge
# Goshen
# Canon AFB
# Bratenhaul
# Wolf Creek drainage
# Commerce Cityy
# Commerce City to Henderson
# Mount Hood parkdale
# Prattesville
# Cashers
# Altomont
# Ten Lakes scenic area; border
# Emory-Yantis
# Television program
# Interstate 40
# Saint Petersburg Causeway
# Fort Carson ; I-25 south
# Milstadt
# San Fransisco
# Nomran
# Simsponville
# over many
# On TV Sunday night football
# Rustico area
# Plattesmouth
# Matinez
# Delary Beach
# Geoje Island
# In distance from Earth
# 3
#               Date      Time                    City State         Country  \
# 0      2008-10-02  20:00:00            Marshalltown    IA   United States
# 1      2008-10-02  05:45:00                Carlsbad    CA   United States
# 2      2010-04-23  15:40:00              Hagerstown    MD   United States
# 3      2008-10-02  20:00:00               Neacroft    NaN  United Kingdom
# 4      2008-10-02  19:52:00              Middletown    NY   United States
# ...           ...       ...                     ...   ...             ...
# 10835  2011-12-25  21:00:00            Cedar Rapids    IA   United States
# 10836  2011-12-25  23:30:00           Port St Lucie    FL   United States
# 10837  2011-12-27  00:00:00  In distance from Earth   NaN            U.S.
# 10838  2011-12-31  18:30:00                    Acme    MI   United States
# 10839  2011-12-31  22:00:00                  Brusly    LA   United States
#
#                Shape       Duration  \
# 0            Chevron    4-5 seconds
# 1              Flash       3-5mins.
# 2              Swarm      5 minutes
# 3      Indiscernible      5 minutes
# 4              Flash          1hr +
# ...              ...            ...
# 10835          Flash  40-50 seconds
# 10836            Egg          3 min
# 10837        Chevron         3 days
# 10838            Orb         3 mins
# 10839       Teardrop      2 minutes
#
#                                                    Link  \
# 0      http://www.nuforc.org/webreports/066/S66098.html
# 1      http://www.nuforc.org/webreports/066/S66032.html
# 2      http://www.nuforc.org/webreports/075/S75159.html
# 3      http://www.nuforc.org/webreports/066/S66038.html
# 4      http://www.nuforc.org/webreports/066/S66026.html
# ...                                                 ...
# 10835  http://www.nuforc.org/webreports/086/S86563.html
# 10836  http://www.nuforc.org/webreports/086/S86545.html
# 10837  http://www.nuforc.org/webreports/086/S86780.html
# 10838  http://www.nuforc.org/webreports/086/S86626.html
# 10839  http://www.nuforc.org/webreports/086/S86807.html
#
#                                                  Comment   Latitude  \
# 0      October 2, 2008  just after 8 p.m.  Marshallto...  42.054200
# 1      10/02/08 just before sunrise, dark skies. Hove...  33.127807
# 2      multiple objects in large formation in the aft...  39.635888
# 3      Cluster of flashing lights spotted It was on M...  50.740960
# 4      Large bright light with aircraft below it show...  41.452987
# ...                                                  ...        ...
# 10835  I saw a large fireball pass over my house at a...  41.977695
# 10836  Bright Orange Orbs flying silent over Port St ...  27.293933
# 10837  NASA has photos of an object in space moving t...        NaN
# 10838  Five orange orbs seen 6:30 pm 110 miles north ...  44.771900
# 10839  Orange, out of the ordinary shape object in th...  30.385300
#
#         Longitude
# 0      -92.930500
# 1     -117.303527
# 2      -77.693988
# 3       -1.678024
# 4      -74.454968
# ...           ...
# 10835  -91.675865
# 10836  -80.350328
# 10837         NaN
# 10838  -85.501500
# 10839  -91.274900
#
# [10840 rows x 11 columns]
# D:\Gilad\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:935: UserWarning: Ignoring URL 'http://www.nuforc.org/webreports/070/S70525.html%20%20I%20saw%20this%20posting,and%20recalled%20a%20night%20in%201994.%20I%20was%20driving%20a%20moving%20truck%20with%202%20helpers%20in%20the%20cab.%20we%20were%20heading%20home%20from%20Bakersfield%20after%20dropping%20off%20a%20load%20of%20furniture.%20I%20saw%20a%20triangle%20shaped%20craft,at%20first%20glance%20I%20thought%20it%20was%20a%20helicopter%20crashing%20in%20a%20field%20across%20the%20hwy,%20as%20we%20got%20closer%20to%20the%20object%20it%20shot%20back%20over%20the%20hwy%20about%20a%201/4%20mile%20in%20front%20of%20us%20off%20to%20the%20right%20side%20of%20the%20hwy.%20%20Then%20it%20seemed%20to%20just%20hover%20for%20a%20couple%20seconds%20and%20then%20it%20came%20right%20at%20my%20truck%20(30%20foot%20moving%20truck)%20I%20thought%20it%20was%20going%20to%20hit%20us%20head%20on.%20As%20it%20got%20within%2020-30%20ft%20it%20went%20right%20above%20us%20and%20over%20the%20cargo%20box,%20the%20craft%20continued%20down%20the%20hwy%20at%20a%20low%20height%20maybe%2025%20ft%20off%20the%20ground%20and%20went%20back%20to%20the%20field%20i%20first%20saw%20it%20in.%20we%20continued%20down%20the%20hwy%20as%20i%20saw%20the%20craft%20in%20my%20side%20view%20mirror%20I%20dont%20recall%20any%20sound%20from%20the%20craft.%20I%20would%20have%20heard%20an%20airplane%20or%20helicopter%20flying%20that%20low.%20I%20tried%20to%20stop%20the%20truck%20and%20pull%20over,but%20the%20other%202%20guys%20with%20me%20kept%20yelling%20don't%20stop%20keep%20going%20lets%20just%20get%20out%20of%20here.%20I%20was%20shaken%20by%20the%20whole%20event%20we%20pulled%20over%20a%20few%20miles%20down%20the%20road.we%20said%20nothing%20to%20each%20other%20at%20that%20time.%20I%20asked%20them%20about%20the%20flying%20object%20we%20all%20saw%202%20days%20later%20and%20they%20both%20denied%20seeing%20anything.%20basic%20design%20of%20craft%20I%20saw%20that%20night.%20%20triangle%20shape%203%20very%20bright%20lights%20they%20lit%20up%20the%20entire%20hwy,%20the%20craft%20had%20to%20be%20atleast%2020ft%20%20and%20I%20still%20to%20this%20date%20have%20never%20seen%20anything%20move%20that%20fast%20with%20so%20much%20control,%20I%20did%20have%20one%20person%20over%20the%20yrs%20tell%20me%20it%20was%20a%20glider,%20I%20dont%20think%20so,%20whatever%20it%20was%20we%20didnt%20make%20it!' with link or location/anchor > 2079 characters since it exceeds Excel's limit for URLS
#   warn("Ignoring URL '%s' with link or location/anchor > %d "
# Alejuela
# N FL; S GA
# Fall River
# Piranguinho
# Sea Isle
# Caxi/Luang Prahbang
# Yellanhalli-643243
# Wildlife Refuge, Medicine Park, Ft. Sill
# Tomaball
# Belbeis
# Loon Mountain Ski Club
# South Myrtle Beach Pier
# Millersville
# DeMotte-Roselawn
# Milk Hill, Alton
# Berkley Heights
# Visalia-Lemoore
# Lexingtob
# Mornas A7 Motorway
# Peabody-Saugus
# Murfeesboro
# Jasonvill
# Jasonvill
# North Massapequa
# Ashgrove
# mile marker 41 garden state parkway
# Stering
# LÃ©vis
# StrÃ¡Å¾ pod Ralskem
# In-flight sighting
# Red Feather area
# Port Jeff Station
# Doha
# Severa Park
# Brick Town
# Mapillville
# Lexingon Heights
# Hummlestown
# Greenbried
# Steinkjer, Nord-TrÃ¸ndelag
# Mechaniscville
# Camp Seph Mack
# Alaska cruise
# Larnca
# Space station video
# Berkley Heights
# Ojibways of Onigaming FN
# LuleÃ¥
# Monett
# North Massapequa
# Soccoro
# Pine Lake Leisure Center
# Tunapuna
# New Symrna beach
# Queenbeyan
# Conway and Economy Boro
# Bloomignton
# Chicao
# Schwencksville
# Hunstville
# West Natcoke
# Monee Manhattan Rd, Monee,on i57 headed north IL 60449
# Sundrland
# KecskemÃ©t
# Cutyhunk Island
# Geneva On Lake
# Stellenboch Montains
# Jacksonveil
# Koeklare
# Wheatly
# Mancheter
# Ufica
# North Bismarck
# Humbel
# Painseville
# Point Pleasent
# Mount Levniya
# Lake Barryessa
# Carlsbad Cavrans
# Everywhere
# West Wartan
# Zihautinejo
# Macias
# Potersville
# Fairfield County-NYC area
# Caarthage
# Mentot
# Zouk Mikael
# Paysone
# Gastings
# Everywhere
# Chaco Culture National Park
# Chaco Culture National Park
# Plum Boro
# Las Vegas; enroute to
# Bablyon
# Fowleville
# Surpise
# NW Crazy Mtns
# Wasilla - Susitna Delta
# wailea, mckenna, Maui, HI
# Gurgaong
# Mechancisburg
# South Burligton
# Fob Shank
# Fredriksburg
# Mirimichi
# North Topsail
# Wasaga Beach - Midland
# Hopkington
# Winter Haven, Eagle Lake
# Coffeville
# Tan Hill, Whiltshire
# Greewood
# Laport
# South Myrtle Beach
# Lake Erling
# Scorrsdale
# Garison
# Point Pleasant Borough
# Layton, Roy, Ogden areas
# Islamorada
# Silvia
# San Saban
# UmeÃ¥
# Mississuaga
# Margate
# Margate
# Delamar Dry Lake
# Plainfeild
# Downingtong
# Boilgee
# Hollywest
# Centrailia
# JESÃšS MARÃA
# Berberton
# Moriches bay area
# Grey's Point in Topping
# Kuiper Crater
# Mescalero Indian Reservation
# Good Year
# Koneohe Bay
# Hockison
# Greenville
# Fagstaff
# Indianpolis
# Kengeri Bangalore. type 'emrohit' on google map
# Knighdale
# Tan Hill, Whiltshire
# Scapoose
# Fedetal way
# Collville
# Edins
# Hailemaile
# White Mountains
# Senatere
# Willimas Lake
# Glenndale
# Granda Hills
# North Shore Oahu
# Angeles City Anunas Brgy
# Chatfeild
# Massuillon
# Lake Tahoe area
# Missourri City
# Rehobeth Beach
# Kenohsa
# Springfeild
# Glendalemingle Dale
# 4
#               Date      Time        City State        Country          Shape  \
# 0      2011-12-31  22:30:00     Orlando    FL  United States          Flash
# 1      2011-12-31  23:52:00     Seattle    WA  United States            Orb
# 2      2012-01-01  00:00:00    Bogalusa    LA  United States  Indiscernible
# 3      2012-01-01  00:00:00     Phoenix    AZ  United States            Egg
# 4      2012-01-01  00:05:00     La Mesa    CA  United States          Flash
# ...           ...       ...         ...   ...            ...            ...
# 10835  2013-08-02  00:50:00    Dumfries    VA  United States            Orb
# 10836  2013-03-01  23:00:00  Charleston    WV  United States        Chevron
# 10837  2013-03-02  19:00:00    Montrose    CO  United States            Egg
# 10838  2013-03-05  16:30:00    Edmonton    AB         Canada      Rectangle
# 10839  2013-03-02  19:00:00    Montrose    CO  United States            Egg
#
#          Duration                                               Link  \
# 0          5 mins   http://www.nuforc.org/webreports/086/S86631.html
# 1       5 minutes   http://www.nuforc.org/webreports/086/S86611.html
# 2          15 min   http://www.nuforc.org/webreports/086/S86558.html
# 3       3 minites   http://www.nuforc.org/webreports/086/S86618.html
# 4           1 min   http://www.nuforc.org/webreports/086/S86598.html
# ...           ...                                                ...
# 10835  30 seconds  http://www.nuforc.org/webreports/100/S100713.html
# 10836   2 minutes   http://www.nuforc.org/webreports/097/S97160.html
# 10837   5 minutes   http://www.nuforc.org/webreports/096/S96580.html
# 10838   2 minutes   http://www.nuforc.org/webreports/096/S96554.html
# 10839   5 minutes   http://www.nuforc.org/webreports/096/S96911.html
#
#                                                  Comment   Latitude  \
# 0      Around 3 groups of 4 light pale lights, just l...  28.519247
# 1      8-10 orange UFO's sited New Years Eve, just be...  47.609046
# 2      Observed a flying light with on sound My wife ...  30.755400
# 3      Red orb   i was smoking outside and seen a orb...  33.535381
# 4      Mr. Davenport,   On Jan. 1, 2012, as I went ou...  32.774466
# ...                                                  ...        ...
# 10835  sphere/fireball falls toward Earth, then, disa...  38.578249
# 10836  Solid triangular lights or light on the underb...  38.356096
# 10837  orange and red oval shaped lights seen by to i...  38.429393
# 10838  I was on a WestJet flight 325 from Toronto to ...  53.522989
# 10839  2 Glowing, super fast moving orbes in the west...  38.429393
#
#         Longitude
# 0      -81.354096
# 1     -122.326028
# 2      -89.913100
# 3     -112.049460
# 4     -117.010075
# ...           ...
# 10835  -77.319564
# 10836  -81.640091
# 10837 -107.885736
# 10838 -113.503961
# 10839 -107.885736
#
# [10840 rows x 11 columns]
# Caniste
# Parm
# Tindall AFB
# Sea of Cortez
# SÃ£o Bento do Sul, SC
# Newcomersotown
# Gainsvile
# Melborune
# Athelstine
# Lawerenceville
# Imaly City
# Lexington to Cincinnati
# Coeur d'Alene Mountains
# Stora BlÃ¥sjÃ¶n
# Camp Mckall
# Hatboroo
# Hendersville
# Cayucoc
# Caladon
# Chesepeake Bay Bridge Tunnel
# Fayettville
# Roseau
# Wilmington
# Noblsville
# Bourmouth
# Los Feliz
# Santa Fe and Albuquerque
# South Hamiltion
# Hove
# Hwy 97 between LaPine & Sunriver
# Okeeckobee
# Santa Rosa Indian Reservation
# Broomfiled- Standley Lake
# Laude
# multiple
# Ocatilio Wells
# Wyndotte
# In-flight sighting
# Chesaprake
# Beloit Township
# Fairfirld
# Winsdor
# Fort Wayn
# Charlestown
# Scene in English movie
# Karne City
# Zelionople
# Crandal
# South Nayack
# Aurburn
# Talahassee
# Clines Corner & Moririty
# New Britian
# Everglades turnpike south
# Bonaie
# Quebradillaa
# New Britian
# Fort Meyers Beach
# SSault Ste. Marie
# Chandlerville
# Qu-appelle
# Merrimcak
# East, Ã£â‚¬â€š
# Monrowville
# Iowa Cuty
# Peidmont
# Ashgrove
# NASA TV
# Fairfax to Woodacre
# Rhein-Main Air Base
# Silveradale
# Cayolargo del Sur Island
# Jabel e akhter
# Stringsville
# Pentang
# Eastern United States
# Many
# Michicot
# Sunerland
# Poughkkepsie
# Graycourt
# Honokowaii
# Layton to Farmington
# Grang junction colorado
# Port Clinto
# Wahcantt
# Monterey Bay area
# Lacy Springs
# Orotin
# Lake Okeechoobee
# New Britghton
# Dewattow
# Coxsacke
# Waelo
# Unspecified city
# Macchu Pichu
# Beechbottom
# UNKNOWN FLYING @ 39,000&quot;
# Murfeesboro
# NÃ¤ssjÃ¶
# Peeble
# Dumont Dune National Park
# Creedmor
# Sant Monica
# Alleouz
# Brownsmills
# Fort Collins
# Punt Gorda
# Pinion Hills
# Barbers Point NAS
# Elgini
# Palm Habor
# Qutong Gorge
# Highway#1 Trans Canada
# Kuparuk Oilfield
# Point Pleasant by the Barnegat Bay
# Warrinhton
# Richards Bay
# Fayatteville
# Talkitna
# Kernesville
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('I-95 south, South Carolina',), **{}).
# Traceback (most recent call last):
#   File "D:\Gilad\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 426, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "D:\Gilad\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 421, in _make_request
#     httplib_response = conn.getresponse()
#   File "D:\Gilad\anaconda3\lib\http\client.py", line 1332, in getresponse
#     response.begin()
#   File "D:\Gilad\anaconda3\lib\http\client.py", line 303, in begin
#     version, status, reason = self._read_status()
#   File "D:\Gilad\anaconda3\lib\http\client.py", line 264, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "D:\Gilad\anaconda3\lib\socket.py", line 669, in readinto
#     return self._sock.recv_into(b)
#   File "D:\Gilad\anaconda3\lib\ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "D:\Gilad\anaconda3\lib\ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\Gilad\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 670, in urlopen
#     httplib_response = self._make_request(
#   File "D:\Gilad\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 428, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#   File "D:\Gilad\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 335, in _raise_timeout
#     raise ReadTimeoutError(
# urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\Gilad\anaconda3\lib\site-packages\requests\adapters.py", line 439, in send
#     resp = conn.urlopen(
#   File "D:\Gilad\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 752, in urlopen
#     return self.urlopen(
#   File "D:\Gilad\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 752, in urlopen
#     return self.urlopen(
#   File "D:\Gilad\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 724, in urlopen
#     retries = retries.increment(
#   File "D:\Gilad\anaconda3\lib\site-packages\urllib3\util\retry.py", line 439, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=I-95+south%2C+South+Carolina&format=json&limit=1&accept-language=en (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\Gilad\anaconda3\lib\site-packages\geopy\adapters.py", line 383, in _request
#     resp = self.session.get(url, timeout=timeout, headers=headers)
#   File "D:\Gilad\anaconda3\lib\site-packages\requests\sessions.py", line 543, in get
#     return self.request('GET', url, **kwargs)
#   File "D:\Gilad\anaconda3\lib\site-packages\requests\sessions.py", line 530, in request
#     resp = self.send(prep, **send_kwargs)
#   File "D:\Gilad\anaconda3\lib\site-packages\requests\sessions.py", line 643, in send
#     r = adapter.send(request, **kwargs)
#   File "D:\Gilad\anaconda3\lib\site-packages\requests\adapters.py", line 516, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=I-95+south%2C+South+Carolina&format=json&limit=1&accept-language=en (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\Gilad\anaconda3\lib\site-packages\geopy\extra\rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#   File "D:\Gilad\anaconda3\lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "D:\Gilad\anaconda3\lib\site-packages\geopy\geocoders\nominatim.py", line 294, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "D:\Gilad\anaconda3\lib\site-packages\geopy\geocoders\base.py", line 360, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "D:\Gilad\anaconda3\lib\site-packages\geopy\adapters.py", line 373, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "D:\Gilad\anaconda3\lib\site-packages\geopy\adapters.py", line 395, in _request
#     raise GeocoderUnavailable(message)
# geopy.exc.GeocoderUnavailable: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=I-95+south%2C+South+Carolina&format=json&limit=1&accept-language=en (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# RateLimiter caught an error, retrying (1/2 tries). Called with (*('I-95 south, South Carolina',), **{}).
# Traceback (most recent call last):
#   File "D:\Gilad\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 426, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "D:\Gilad\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 421, in _make_request
#     httplib_response = conn.getresponse()
#   File "D:\Gilad\anaconda3\lib\http\client.py", line 1332, in getresponse
#     response.begin()
#   File "D:\Gilad\anaconda3\lib\http\client.py", line 303, in begin
#     version, status, reason = self._read_status()
#   File "D:\Gilad\anaconda3\lib\http\client.py", line 264, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "D:\Gilad\anaconda3\lib\socket.py", line 669, in readinto
#     return self._sock.recv_into(b)
#   File "D:\Gilad\anaconda3\lib\ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "D:\Gilad\anaconda3\lib\ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\Gilad\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 670, in urlopen
#     httplib_response = self._make_request(
#   File "D:\Gilad\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 428, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#   File "D:\Gilad\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 335, in _raise_timeout
#     raise ReadTimeoutError(
# urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\Gilad\anaconda3\lib\site-packages\requests\adapters.py", line 439, in send
#     resp = conn.urlopen(
#   File "D:\Gilad\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 752, in urlopen
#     return self.urlopen(
#   File "D:\Gilad\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 752, in urlopen
#     return self.urlopen(
#   File "D:\Gilad\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 724, in urlopen
#     retries = retries.increment(
#   File "D:\Gilad\anaconda3\lib\site-packages\urllib3\util\retry.py", line 439, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=I-95+south%2C+South+Carolina&format=json&limit=1&accept-language=en (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\Gilad\anaconda3\lib\site-packages\geopy\adapters.py", line 383, in _request
#     resp = self.session.get(url, timeout=timeout, headers=headers)
# ...
#   File "D:\Gilad\anaconda3\lib\site-packages\geopy\adapters.py", line 383, in _request
#     resp = self.session.get(url, timeout=timeout, headers=headers)
#   File "D:\Gilad\anaconda3\lib\site-packages\requests\sessions.py", line 543, in get
#     return self.request('GET', url, **kwargs)
#   File "D:\Gilad\anaconda3\lib\site-packages\requests\sessions.py", line 530, in request
#     resp = self.send(prep, **send_kwargs)
#   File "D:\Gilad\anaconda3\lib\site-packages\requests\sessions.py", line 643, in send
#     r = adapter.send(request, **kwargs)
#   File "D:\Gilad\anaconda3\lib\site-packages\requests\adapters.py", line 516, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=I-95+south%2C+South+Carolina&format=json&limit=1&accept-language=en (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\Gilad\anaconda3\lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "D:\Gilad\anaconda3\lib\site-packages\geopy\geocoders\nominatim.py", line 294, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "D:\Gilad\anaconda3\lib\site-packages\geopy\geocoders\base.py", line 360, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "D:\Gilad\anaconda3\lib\site-packages\geopy\adapters.py", line 373, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "D:\Gilad\anaconda3\lib\site-packages\geopy\adapters.py", line 395, in _request
#     raise GeocoderUnavailable(message)
# geopy.exc.GeocoderUnavailable: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=I-95+south%2C+South+Carolina&format=json&limit=1&accept-language=en (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# I-95 south
# Kissimme
# Ridge Mountain Elkins
# Kuparuk Oilfield
# South of Sarasota
# Stewarts town
# Glenallen
# Supulpa
# 5
#               Date      Time                City State        Country    Shape  \
# 0      2013-03-05  18:15:00         Bakersfield    CA  United States    Flash
# 1      2013-03-05  20:00:00              Normal    IL  United States  Chevron
# 2      2013-03-05  20:00:00  San Jose del Cabo    NaN         Mexico    Flash
# 3      2013-08-02  01:15:00       Franklinville    NJ  United States      Egg
# 4      2013-08-02  01:30:00             Orlando    FL  United States    Flash
# ...           ...       ...                 ...   ...            ...      ...
# 10835  2014-07-04  23:00:00             Chicago    IL  United States    Flash
# 10836  2014-07-04  23:00:00          Brookfield    IL  United States  Diamond
# 10837  2014-07-04  23:00:00              Eugene    OR  United States      NaN
# 10838  2014-07-04  23:00:00          Fort Wayne    IN  United States    Flash
# 10839  2014-07-04  23:03:00               Union    OH  United States      Orb
#
#            Duration                                               Link  \
# 0      1-2  minutes   http://www.nuforc.org/webreports/096/S96555.html
# 1          05:00:00   http://www.nuforc.org/webreports/097/S97033.html
# 2         2 seconds   http://www.nuforc.org/webreports/096/S96557.html
# 3        10 seconds  http://www.nuforc.org/webreports/100/S100712.html
# 4        <2 Minutes  http://www.nuforc.org/webreports/100/S100710.html
# ...             ...                                                ...
# 10835    15 minutes  http://www.nuforc.org/webreports/111/S111142.html
# 10836   1-2 minutes  http://www.nuforc.org/webreports/111/S111104.html
# 10837   2.5 minutes  http://www.nuforc.org/webreports/111/S111255.html
# 10838     2 minutes  http://www.nuforc.org/webreports/111/S111344.html
# 10839    10 minutes  http://www.nuforc.org/webreports/111/S111098.html
#
#                                                  Comment   Latitude  \
# 0      Bright Light In Sky Suddenly Disappears I was ...  35.343998
# 1      Slow moving triangle craft, bright white light...  40.528067
# 2      On 3/5/13 in the evening, between 6:00 PM â€“ ...  23.059836
# 3      green oblong oval with greenish glow; very fas...  39.618200
# 4      Four Fireballs in Formation over Orlando I liv...  28.519247
# ...                                                  ...        ...
# 10835  4 unidentified red light objects disappeared &...  41.879912
# 10836  Flying in a diamond formation, four diamond sh...  41.825400
# 10837  ORANGE CYLINDER OVER EUGENE ON THE 4th IT WAS ...  44.039545
# 10838  A red flashing object seen by by 3 people in F...  41.093370
# 10839  Initially saw five orange ball-shaped objects ...  39.912295
#
#         Longitude
# 0     -119.040893
# 1      -88.980233
# 2     -109.702515
# 3      -75.075700
# 4      -81.354096
# ...           ...
# 10835  -87.668018
# 10836  -87.845400
# 10837 -123.125157
# 10838  -85.145573
# 10839  -84.304022
#
# [10840 rows x 11 columns]
# Port Berre
# Rowlett, Sachse
# Loron
# Lahaiiina
# Uknown
# Tampa Vay viewing from west
# Kennett Sqaure
# Lizerne County
# Merrit
# Goodletsville
# Indianpolis
# At sea
# Bainbrodge
# Weldon Springs
# Hanford Nuclear facility
# South Topsail Beach
# Greeenwood
# Murrels Inlet
# New Liskard
# Witch Wells
# Okhay Owingeh
# Litchfeild
# Ocean Island Beach
# SerlingHights
# Southbend
# Narian
# Central Paint
# Naniamo
# Unspecified location
# Ducannon
# Location unspecified by witness
# Columia
# Heswall
# Jackhorn
# Marreo
# Wlimington
# Iowa City Hwy 218 north, I-380 north, Cedar Rapids)
# Southbend
# Southbend
# Gila Bend-Aztec
# Saint Loisville
# Biddeford Pool
# North Fond du Llac
# Carrolltom
# Witch Wells
# Meppel
# Rehoboth Beach
# Marion-Morganton
# Ehete
# Garden State Parkway around 40 mile mark
# Interstate 10
# Wilksboro
# Vero Beach
# SÃ£o SebastiÃ£o SP
# Wilmont
# Galior
# Isle of Palm
# Hearthill
# Murpheesboro
# Churubuaco
# Murrell's inland
# Taveriner
# Estelle Manor
# Eurodisney/Marne La VallÃ©e
# Gonzalas
# Lee Summitt
# Demands
# Pompono Beach
# North Greenbush
# Westnewfield
# Selma-Coos Bay
# Minot
# Kangirsujuaq
# Earth's Moon
# Pine Knoll Shores
# Louisville St Mathewes
# Mount Rose Wilderness, Reno
# South Chicago Height
# Nuese River Mouth
# Tukwilla
# Whyndanch
# Sandy Hook State Park
# Kaneoeh
# Colorado Sorings
# Idaho Springs to Dumont
# Kiambu
# ?
# San Luis Obisbo
# Colordao Springs
# Gloucestet
# Parma
# Military training site
# Unspecified location
# Highlany
# Rocky Poiint
# Bamber Lakes
# Orangburg
# Tri-cities and Yakima County
# Callallen
# Mentor Headlands
# I-24   80 to 74 mile marker
# Encinitas Carlsbad
# Homstead
# Saint Petersrburg
# Solromar
# Reddinton Beach
# Hamlake
# Platsmouth
# Chiloquin
# Cincinatti
# Gila River Indian Reservation
# Nortvale
# Beloit
# Cyrus, WV US 52 North â€¢ Coordinates: 38Â°18&#8242;19&#8243;N
# Russleville
# Buffalo Creek Area Campground
# Gamrbrills
# Yakima Firing Center, Yakima
# Bangor and Bloomingdale
# Seacaucus
# Keansburgh
# Cascabels
# Alden Township
# Housesprings
# Coshocron
# North Tonnawanda
# Twenty Nine Palms
# Winnaway
# Ahmadi
# Beeville-Kennedy
# Michelton/Brisbane
# Catonsvill
# Redond Beach
# Downingtown
# Black Rock Campgroud Joshua tree
# Dundee to Brighton
# Umpqua Nat. Forest
# Mount Poccono
# Menifeeca
# Manchester to Baltimore, MD
# Wilows
# 6
#               Date      Time              City State        Country  \
# 0      2014-07-04  23:03:00           Bolivar    MO  United States
# 1      2014-07-12  21:12:00            Austin    TX  United States
# 2      2014-07-12  21:15:00           Leander    TX  United States
# 3      2014-07-12  21:15:00            Austin    TX  United States
# 4      2014-07-12  21:15:00        Monticello    MS  United States
# ...           ...       ...               ...   ...            ...
# 10835  2015-11-07  18:10:00         San Diego    CA  United States
# 10836  2015-11-07  18:10:00     Moreno Valley    CA  United States
# 10837  2015-11-07  18:10:00  Huntington Beach    CA  United States
# 10838  2015-11-07  18:10:00      Apple Valley    CA  United States
# 10839  2015-11-07  18:10:00         Elk Grove    CA  United States
#
#                Shape     Duration  \
# 0              Other    2 minutes
# 1              Flash   15 seconds
# 2              Flash  3-5 seconds
# 3              Flash  3-4 seconds
# 4              Flash   ~5 seconds
# ...              ...          ...
# 10835            Egg    5 minutes
# 10836          Other    5 minutes
# 10837            Orb    5 minutes
# 10838  Indiscernible  >10 minutes
# 10839            Orb  3-4 minutes
#
#                                                     Link  \
# 0      http://www.nuforc.org/webreports/111/S111202.html
# 1      http://www.nuforc.org/webreports/111/S111467.html
# 2      http://www.nuforc.org/webreports/111/S111504.html
# 3      http://www.nuforc.org/webreports/111/S111494.html
# 4      http://www.nuforc.org/webreports/111/S111456.html
# ...                                                  ...
# 10835  http://www.nuforc.org/webreports/123/S123685.html
# 10836  http://www.nuforc.org/webreports/123/S123578.html
# 10837  http://www.nuforc.org/webreports/123/S123672.html
# 10838  http://www.nuforc.org/webreports/123/S123764.html
# 10839  http://www.nuforc.org/webreports/123/S123692.html
#
#                                                  Comment   Latitude  \
# 0      Elliptical shaped fireball. at 3 after 2300 i ...  37.642200
# 1      Two Super fast moving white lights in early ev...  30.308469
# 2      Hi-Speed, Low Altitude White Light ORB Sightin...  30.524145
# 3      Two bright white lights chasing each other on ...  30.308469
# 4      This was a fireball that streaked across the s...  31.569200
# ...                                                  ...        ...
# 10835  Traveling west on the 52, in the sky was a lar...  32.787229
# 10836  Alien ship spotted over moreno valley californ...  33.929631
# 10837  I was driving my car with my two kids and my o...  33.688433
# 10838  Object falling, multiple bursts of orange ligh...  34.537616
# 10839  Silent bright object sending out luminous beam...  38.394469
#
#         Longitude
# 0      -93.399600
# 1      -97.760112
# 2      -97.926762
# 3      -97.760112
# 4      -90.109700
# ...           ...
# 10835 -117.140268
# 10836 -117.216031
# 10837 -118.004994
# 10838 -117.173101
# 10839 -121.371859
#
# [10840 rows x 11 columns]
# Drove/Soller
# Marrietta
# Rockvile
# Ouchita National Forest
# Olmsteadville
# Frostburg, Lavale
# Bistib
# Vannuys
# Sicklerviller
# Some where between Fernley and shurz
# Gonzales
# Tuscarora Indian Reservation
# Sears Point Raceway
# Anderson or Oconee
# Willglen
# Bahgram
# Wynanskill
# Saint Fracois Xavier
# Com/Lugano
# Encintas
# Mismisburg
# Eastaboba
# Unspecified
# Chihlowie
# Aloharetta
# Manoa Hills
# Groom Creek wilderness area
# JÃ¶nkÃ¶ping
# Waldoboro
# Woods Canyon Lake
# Slippery Rock Township, near New Castle
# Roasharon
# Rhien
# Saint Clair Shored
# El Soreno
# Hendersom
# Old Town Katy
# Weverville
# Connelsville
# Birmigham
# Dorset
# Gulf of Mexico
# Lexinton
# Palm Spings
# Rather not say.
# Baldwin Borough
# Mayfeld
# Groton Long Point
# Vellore/Hyderabad/Bangalore
# VÃ¤sterÃ¥s
# Phalaborwa
# McHenrry
# Levene
# Curchorem, Savordem
# Joppatown
# Bolivar, Hermitage, and Urbana
# Ran home Santa Fe
# Ocala
# West Farmington
# Wheeler AAF
# Antinito
# Lake Wataree
# Lakveville
# Ocean & Monmouth Counties
# Hartebeespoortdam
# DeLuz
# Harlansburgh
# Southwest UK
# Attelboro
# Musquodoboit Harbor
# Mountatin Top
# Wentzvillle
# Las Vegas    in desert
# Boring, Sandy area
# Kings Canyon National Parks
# Tryon Equestrian Center
# Manat
# I-196 at Mile Marker 7
# Lower Haines City
# Mytle Beach
# Channel Islands Point Magu
# Deer Trailer
# Between Wabash and Marion onq5
# Blue Star Memorial Highway
# Bogie Sound
# ChajarÃ­ Entre RÃ­os
# Joshua Tree-Twenty Nine Palms
# Indian Rock Beach
# North Hardeeville
# Sagamok First Nation
# Jacksonville Flat & Atlanta
# New Mexico border
# SÃ£o Paulo
# Gulf of Mexico
# Huntingtion
# Ã‡anakkale/Ã‡an
# East Irondequoit
# South Myrtle Beach
# Leander-Jarrell
# Millwood Community to the outskirts of Andrews
# Wigan
# Lakside
# Wylie and Rowlett
# Placheville
# Tirana
# Great Smokey Mountains National Park
# QuÃ©bec City
# Clarkdale community
# Fort Fraiser
# Forrestville
# Banner Springs
# Lake Tanis
# Madurai
# Syracuse to Phoenix
# Stering Heights
# Gulf of Mexico SMI 69 B
# Phoenix to Syracuse
# New Britian
# Winnemucca
# Emerald isl
# Soringfield
# Bamber Lakes
# Pittsfielsd
# Curtis Bau
# San Luis PotosÃ­
# Nappannee
# La Quinta, Indian Wells, Palm Desert
# Perrysburgh
# Veduawoo
# Port Colbourne
# not sure
# Belpit
# South Belot
# Navoo
# Cherry Springs Community
# In-flight
# Woodinvile
# Atascocta
# Donaldsonville
# Sahaurita
# MckeesRocksr
# Mananlapan
# Mokuliea
# Concord - Penecook
# Hopulikit
# Maycomb
# Pinion Hills
# Fort Chafee
# Locohills
# Perradeniya
# Gomardhi
# Locohills
# CuraÃ§ao
# Lake Umatilla; John Day Dam
# Christhcurch
# Multiple
# Florence Jct.
# Eden Prarie
# Camp McGregor
# Uinta Mountian Range
# Bemow Piskie
# 7
#               Date      Time          City State        Country          Shape  \
# 0      2015-11-07  18:10:00  Santa Monica    CA  United States          Flash
# 1      2015-11-07  18:10:00     Las Vegas    NV  United States  Indiscernible
# 2      2015-11-07  18:10:00     San Diego    CA  United States          Flash
# 3      2015-11-07  18:10:00    Long Beach    CA  United States            Orb
# 4      2015-11-07  18:12:00  Gardnerville    NV  United States           Cone
# ...           ...       ...           ...   ...            ...            ...
# 10835  2017-08-27  22:00:00     Ellenwood    GA  United States          Flash
# 10836  2017-08-27  22:00:00        Girard    KS  United States          Flash
# 10837  2017-08-27  22:10:00   Kansas City    MO  United States          Flash
# 10838  2017-08-27  23:10:00       Calgary    AB         Canada          Other
# 10839  2017-08-28  05:20:00      Wendover    NV  United States          Other
#
#              Duration                                               Link  \
# 0      20-120 seconds  http://www.nuforc.org/webreports/123/S123661.html
# 1          5+ minutes  http://www.nuforc.org/webreports/123/S123645.html
# 2           2 minutes  http://www.nuforc.org/webreports/123/S123714.html
# 3        30 seconds +  http://www.nuforc.org/webreports/123/S123605.html
# 4            1 minute  http://www.nuforc.org/webreports/123/S123726.html
# ...               ...                                                ...
# 10835       10 second  http://www.nuforc.org/webreports/135/S135950.html
# 10836      10 minutes  http://www.nuforc.org/webreports/135/S135955.html
# 10837       5 seconds  http://www.nuforc.org/webreports/135/S135931.html
# 10838      45 seconds  http://www.nuforc.org/webreports/135/S135940.html
# 10839      30 seconds  http://www.nuforc.org/webreports/135/S135937.html
#
#                                                  Comment   Latitude  \
# 0      A clear night sky in Santa Monica and near the...  34.023428
# 1      Large bright flood light over S.W. Las Vegas. ...  36.141246
# 2      From stone ranch elementary school towards wes...  32.787229
# 3      Brightest light in the western clear sky as bi...  33.790023
# 4      Bright object traveled south to north through ...  38.830852
# ...                                                  ...        ...
# 10835  My friend and I walked around the back of my h...  33.635600
# 10836  Big orange light glowing in the woods at night...  37.511200
# 10837  Driving along highway 35 North and saw an obje...  39.100835
# 10838  Triangle UFO spotted at the University of Calg...  51.042379
# 10839  Unidentified object 5:20am, before sunrise.  L...  40.742670
#
#         Longitude
# 0     -118.481677
# 1     -115.186592
# 2     -117.140268
# 3     -118.173105
# 4     -119.697439
# ...           ...
# 10835  -84.260500
# 10836  -94.838000
# 10837  -94.564479
# 10838 -114.057442
# 10839 -114.072087
#
# [10840 rows x 11 columns]
